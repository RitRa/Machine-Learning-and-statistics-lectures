# %% [markdown]
# Tutorial on keras
# https://gist.github.com/NiharG15/cd8272c9639941cf8f481a7c4478d525

# %%
import numpy as np

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
iris_data = load_iris() # load the iris dataset

# %%
print('Example data: ')
print(iris_data.data[:5])
print('Example labels: ')
print(iris_data.target[:5])
# Out:
# Example data:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
# Example labels:
# [0 0 0 0 0]

# %%
x = iris_data.data
y_ = iris_data.target.reshape(-1, 1) # Convert data to a single column

# %%
# One Hot encode the class labels
encoder = OneHotEncoder(sparse=False)
y = encoder.fit_transform(y_)
#print(y)
# Out:
# //anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
# Split the data for training and testing
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.20)

# %%
# Build the model

model = Sequential()

model.add(Dense(10, input_shape=(4,), activation='relu', name='fc1'))
model.add(Dense(10, activation='relu', name='fc2'))
model.add(Dense(3, activation='softmax', name='output'))

# %%
# Adam optimizer with learning rate of 0.001
optimizer = Adam(lr=0.001)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
print('Neural Network Model Summary: ')
print(model.summary())
# Out:
# Neural Network Model Summary:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# fc1 (Dense)                  (None, 10)                50
# _________________________________________________________________
# fc2 (Dense)                  (None, 10)                110
# _________________________________________________________________
# output (Dense)               (None, 3)                 33
# =================================================================
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Train the model
model.fit(train_x, train_y, verbose=2, batch_size=5, epochs=200)
# Out:
# WARNING:tensorflow:From //anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/200
#  - 1s - loss: 1.6805 - accuracy: 0.3417
# Epoch 2/200
#  - 0s - loss: 1.4631 - accuracy: 0.3417
# Epoch 3/200
#  - 0s - loss: 1.3309 - accuracy: 0.3417
# Epoch 4/200
#  - 0s - loss: 1.2380 - accuracy: 0.3417
# Epoch 5/200
#  - 0s - loss: 1.1519 - accuracy: 0.2000
# Epoch 6/200
#  - 0s - loss: 1.0683 - accuracy: 0.2333
# Epoch 7/200
#  - 0s - loss: 0.9801 - accuracy: 0.6500
# Epoch 8/200
#  - 0s - loss: 0.8989 - accuracy: 0.7917
# Epoch 9/200
#  - 0s - loss: 0.8310 - accuracy: 0.8667
# Epoch 10/200
#  - 0s - loss: 0.7687 - accuracy: 0.8500
# Epoch 11/200
#  - 0s - loss: 0.7107 - accuracy: 0.8333
# Epoch 12/200
#  - 0s - loss: 0.6607 - accuracy: 0.8417
# Epoch 13/200
#  - 0s - loss: 0.6136 - accuracy: 0.8417
# Epoch 14/200
#  - 0s - loss: 0.5732 - accuracy: 0.8500
# Epoch 15/200
#  - 0s - loss: 0.5361 - accuracy: 0.8750
# Epoch 16/200
#  - 0s - loss: 0.5051 - accuracy: 0.8833
# Epoch 17/200
#  - 0s - loss: 0.4754 - accuracy: 0.9167
# Epoch 18/200
#  - 0s - loss: 0.4488 - accuracy: 0.9250
# Epoch 19/200
#  - 0s - loss: 0.4264 - accuracy: 0.9500
# Epoch 20/200
#  - 0s - loss: 0.3931 - accuracy: 0.9333
# Epoch 21/200
#  - 0s - loss: 0.3711 - accuracy: 0.9333
# Epoch 22/200
#  - 0s - loss: 0.3485 - accuracy: 0.9333
# Epoch 23/200
#  - 0s - loss: 0.3318 - accuracy: 0.9583
# Epoch 24/200
#  - 0s - loss: 0.3183 - accuracy: 0.9417
# Epoch 25/200
#  - 0s - loss: 0.3002 - accuracy: 0.9500
# Epoch 26/200
#  - 0s - loss: 0.2862 - accuracy: 0.9667
# Epoch 27/200
#  - 0s - loss: 0.2753 - accuracy: 0.9500
# Epoch 28/200
#  - 0s - loss: 0.2627 - accuracy: 0.9750
# Epoch 29/200
#  - 0s - loss: 0.2554 - accuracy: 0.9583
# Epoch 30/200
#  - 0s - loss: 0.2434 - accuracy: 0.9500
# Epoch 31/200
#  - 0s - loss: 0.2347 - accuracy: 0.9583
# Epoch 32/200
#  - 0s - loss: 0.2267 - accuracy: 0.9500
# Epoch 33/200
#  - 0s - loss: 0.2174 - accuracy: 0.9500
# Epoch 34/200
#  - 0s - loss: 0.2075 - accuracy: 0.9583
# Epoch 35/200
#  - 0s - loss: 0.2024 - accuracy: 0.9667
# Epoch 36/200
#  - 0s - loss: 0.1944 - accuracy: 0.9667
# Epoch 37/200
#  - 0s - loss: 0.1905 - accuracy: 0.9500
# Epoch 38/200
#  - 0s - loss: 0.1840 - accuracy: 0.9667
# Epoch 39/200
#  - 0s - loss: 0.1791 - accuracy: 0.9583
# Epoch 40/200
#  - 0s - loss: 0.1717 - accuracy: 0.9667
# Epoch 41/200
#  - 0s - loss: 0.1674 - accuracy: 0.9667
# Epoch 42/200
#  - 0s - loss: 0.1649 - accuracy: 0.9750
# Epoch 43/200
#  - 0s - loss: 0.1624 - accuracy: 0.9667
# Epoch 44/200
#  - 0s - loss: 0.1550 - accuracy: 0.9583
# Epoch 45/200
#  - 0s - loss: 0.1533 - accuracy: 0.9667
# Epoch 46/200
#  - 0s - loss: 0.1493 - accuracy: 0.9750
# Epoch 47/200
#  - 0s - loss: 0.1420 - accuracy: 0.9750
# Epoch 48/200
#  - 0s - loss: 0.1399 - accuracy: 0.9583
# Epoch 49/200
#  - 0s - loss: 0.1355 - accuracy: 0.9667
# Epoch 50/200
#  - 0s - loss: 0.1341 - accuracy: 0.9583
# Epoch 51/200
#  - 0s - loss: 0.1292 - accuracy: 0.9667
# Epoch 52/200
#  - 0s - loss: 0.1265 - accuracy: 0.9667
# Epoch 53/200
#  - 0s - loss: 0.1249 - accuracy: 0.9750
# Epoch 54/200
#  - 0s - loss: 0.1219 - accuracy: 0.9750
# Epoch 55/200
#  - 0s - loss: 0.1208 - accuracy: 0.9667
# Epoch 56/200
#  - 0s - loss: 0.1207 - accuracy: 0.9750
# Epoch 57/200
#  - 0s - loss: 0.1168 - accuracy: 0.9667
# Epoch 58/200
#  - 0s - loss: 0.1142 - accuracy: 0.9583
# Epoch 59/200
#  - 0s - loss: 0.1129 - accuracy: 0.9750
# Epoch 60/200
#  - 0s - loss: 0.1116 - accuracy: 0.9667
# Epoch 61/200
#  - 0s - loss: 0.1082 - accuracy: 0.9667
# Epoch 62/200
#  - 0s - loss: 0.1037 - accuracy: 0.9833
# Epoch 63/200
#  - 0s - loss: 0.1037 - accuracy: 0.9750
# Epoch 64/200
#  - 0s - loss: 0.1025 - accuracy: 0.9750
# Epoch 65/200
#  - 0s - loss: 0.0995 - accuracy: 0.9833
# Epoch 66/200
#  - 0s - loss: 0.1044 - accuracy: 0.9583
# Epoch 67/200
#  - 0s - loss: 0.0980 - accuracy: 0.9750
# Epoch 68/200
#  - 0s - loss: 0.0957 - accuracy: 0.9750
# Epoch 69/200
#  - 0s - loss: 0.0941 - accuracy: 0.9833
# Epoch 70/200
#  - 0s - loss: 0.0937 - accuracy: 0.9750
# Epoch 71/200
#  - 0s - loss: 0.0902 - accuracy: 0.9667
# Epoch 72/200
#  - 0s - loss: 0.0896 - accuracy: 0.9833
# Epoch 73/200
#  - 0s - loss: 0.0885 - accuracy: 0.9833
# Epoch 74/200
#  - 0s - loss: 0.0890 - accuracy: 0.9667
# Epoch 75/200
#  - 0s - loss: 0.0910 - accuracy: 0.9750
# Epoch 76/200
#  - 0s - loss: 0.0894 - accuracy: 0.9667
# Epoch 77/200
#  - 0s - loss: 0.0838 - accuracy: 0.9833
# Epoch 78/200
#  - 0s - loss: 0.0826 - accuracy: 0.9833
# Epoch 79/200
#  - 0s - loss: 0.0839 - accuracy: 0.9833
# Epoch 80/200
#  - 0s - loss: 0.0830 - accuracy: 0.9667
# Epoch 81/200
#  - 0s - loss: 0.0815 - accuracy: 0.9750
# Epoch 82/200
#  - 0s - loss: 0.0811 - accuracy: 0.9833
# Epoch 83/200
#  - 0s - loss: 0.0787 - accuracy: 0.9667
# Epoch 84/200
#  - 0s - loss: 0.0778 - accuracy: 0.9833
# Epoch 85/200
#  - 0s - loss: 0.0805 - accuracy: 0.9667
# Epoch 86/200
#  - 0s - loss: 0.0797 - accuracy: 0.9667
# Epoch 87/200
#  - 0s - loss: 0.0791 - accuracy: 0.9667
# Epoch 88/200
#  - 0s - loss: 0.0751 - accuracy: 0.9833
# Epoch 89/200
#  - 0s - loss: 0.0717 - accuracy: 0.9833
# Epoch 90/200
#  - 0s - loss: 0.0743 - accuracy: 0.9750
# Epoch 91/200
#  - 0s - loss: 0.0752 - accuracy: 0.9833
# Epoch 92/200
#  - 0s - loss: 0.0724 - accuracy: 0.9750
# Epoch 93/200
#  - 0s - loss: 0.0771 - accuracy: 0.9750
# Epoch 94/200
#  - 0s - loss: 0.0766 - accuracy: 0.9750
# Epoch 95/200
#  - 0s - loss: 0.0816 - accuracy: 0.9667
# Epoch 96/200
#  - 0s - loss: 0.0781 - accuracy: 0.9667
# Epoch 97/200
#  - 0s - loss: 0.0670 - accuracy: 0.9750
# Epoch 98/200
#  - 0s - loss: 0.0692 - accuracy: 0.9833
# Epoch 99/200
#  - 0s - loss: 0.0658 - accuracy: 0.9833
# Epoch 100/200
#  - 0s - loss: 0.0696 - accuracy: 0.9667
# Epoch 101/200
#  - 0s - loss: 0.0660 - accuracy: 0.9833
# Epoch 102/200
#  - 0s - loss: 0.0689 - accuracy: 0.9833
# Epoch 103/200
#  - 0s - loss: 0.0634 - accuracy: 0.9833
# Epoch 104/200
#  - 0s - loss: 0.0660 - accuracy: 0.9750
# Epoch 105/200
#  - 0s - loss: 0.0659 - accuracy: 0.9833
# Epoch 106/200
#  - 0s - loss: 0.0645 - accuracy: 0.9750
# Epoch 107/200
#  - 0s - loss: 0.0645 - accuracy: 0.9833
# Epoch 108/200
#  - 0s - loss: 0.0618 - accuracy: 0.9833
# Epoch 109/200
#  - 0s - loss: 0.0617 - accuracy: 0.9833
# Epoch 110/200
#  - 0s - loss: 0.0655 - accuracy: 0.9750
# Epoch 111/200
#  - 0s - loss: 0.0617 - accuracy: 0.9833
# Epoch 112/200
#  - 0s - loss: 0.0625 - accuracy: 0.9667
# Epoch 113/200
#  - 0s - loss: 0.0595 - accuracy: 0.9833
# Epoch 114/200
#  - 0s - loss: 0.0621 - accuracy: 0.9750
# Epoch 115/200
#  - 0s - loss: 0.0581 - accuracy: 0.9833
# Epoch 116/200
#  - 0s - loss: 0.0619 - accuracy: 0.9667
# Epoch 117/200
#  - 0s - loss: 0.0574 - accuracy: 0.9833
# Epoch 118/200
#  - 0s - loss: 0.0569 - accuracy: 0.9833
# Epoch 119/200
#  - 0s - loss: 0.0576 - accuracy: 0.9833
# Epoch 120/200
#  - 0s - loss: 0.0587 - accuracy: 0.9833
# Epoch 121/200
#  - 0s - loss: 0.0580 - accuracy: 0.9750
# Epoch 122/200
#  - 0s - loss: 0.0570 - accuracy: 0.9833
# Epoch 123/200
#  - 0s - loss: 0.0585 - accuracy: 0.9750
# Epoch 124/200
#  - 0s - loss: 0.0563 - accuracy: 0.9750
# Epoch 125/200
#  - 0s - loss: 0.0549 - accuracy: 0.9833
# Epoch 126/200
#  - 0s - loss: 0.0561 - accuracy: 0.9833
# Epoch 127/200
#  - 0s - loss: 0.0585 - accuracy: 0.9833
# Epoch 128/200
#  - 0s - loss: 0.0553 - accuracy: 0.9833
# Epoch 129/200
#  - 0s - loss: 0.0559 - accuracy: 0.9833
# Epoch 130/200
#  - 0s - loss: 0.0527 - accuracy: 0.9833
# Epoch 131/200
#  - 0s - loss: 0.0510 - accuracy: 0.9917
# Epoch 132/200
#  - 0s - loss: 0.0549 - accuracy: 0.9833
# Epoch 133/200
#  - 0s - loss: 0.0547 - accuracy: 0.9833
# Epoch 134/200
#  - 0s - loss: 0.0561 - accuracy: 0.9750
# Epoch 135/200
#  - 0s - loss: 0.0526 - accuracy: 0.9833
# Epoch 136/200
#  - 0s - loss: 0.0526 - accuracy: 0.9833
# Epoch 137/200
#  - 0s - loss: 0.0533 - accuracy: 0.9917
# Epoch 138/200
#  - 0s - loss: 0.0513 - accuracy: 0.9833
# Epoch 139/200
#  - 0s - loss: 0.0526 - accuracy: 0.9750
# Epoch 140/200
#  - 0s - loss: 0.0479 - accuracy: 0.9917
# Epoch 141/200
#  - 0s - loss: 0.0490 - accuracy: 0.9917
# Epoch 142/200
#  - 0s - loss: 0.0516 - accuracy: 0.9833
# Epoch 143/200
#  - 0s - loss: 0.0492 - accuracy: 0.9750
# Epoch 144/200
#  - 0s - loss: 0.0473 - accuracy: 0.9833
# Epoch 145/200
#  - 0s - loss: 0.0494 - accuracy: 0.9917
# Epoch 146/200
#  - 0s - loss: 0.0465 - accuracy: 0.9917
# Epoch 147/200
#  - 0s - loss: 0.0490 - accuracy: 0.9833
# Epoch 148/200
#  - 0s - loss: 0.0460 - accuracy: 0.9917
# Epoch 149/200
#  - 0s - loss: 0.0485 - accuracy: 0.9917
# Epoch 150/200
#  - 0s - loss: 0.0466 - accuracy: 0.9917
# Epoch 151/200
#  - 0s - loss: 0.0535 - accuracy: 0.9833
# Epoch 152/200
#  - 0s - loss: 0.0588 - accuracy: 0.9750
# Epoch 153/200
#  - 0s - loss: 0.0442 - accuracy: 0.9833
# Epoch 154/200
#  - 0s - loss: 0.0476 - accuracy: 0.9917
# Epoch 155/200
#  - 0s - loss: 0.0460 - accuracy: 0.9917
# Epoch 156/200
#  - 0s - loss: 0.0463 - accuracy: 0.9917
# Epoch 157/200
#  - 0s - loss: 0.0492 - accuracy: 0.9750
# Epoch 158/200
#  - 0s - loss: 0.0465 - accuracy: 0.9833
# Epoch 159/200
#  - 0s - loss: 0.0525 - accuracy: 0.9750
# Epoch 160/200
#  - 0s - loss: 0.0500 - accuracy: 0.9750
# Epoch 161/200
#  - 0s - loss: 0.0458 - accuracy: 0.9833
# Epoch 162/200
#  - 0s - loss: 0.0441 - accuracy: 0.9833
# Epoch 163/200
#  - 0s - loss: 0.0422 - accuracy: 0.9917
# Epoch 164/200
#  - 0s - loss: 0.0469 - accuracy: 0.9917
# Epoch 165/200
#  - 0s - loss: 0.0421 - accuracy: 0.9917
# Epoch 166/200
#  - 0s - loss: 0.0416 - accuracy: 0.9917
# Epoch 167/200
#  - 0s - loss: 0.0412 - accuracy: 0.9917
# Epoch 168/200
#  - 0s - loss: 0.0418 - accuracy: 0.9917
# Epoch 169/200
#  - 0s - loss: 0.0410 - accuracy: 0.9917
# Epoch 170/200
#  - 0s - loss: 0.0464 - accuracy: 0.9917
# Epoch 171/200
#  - 0s - loss: 0.0435 - accuracy: 0.9833
# Epoch 172/200
#  - 0s - loss: 0.0432 - accuracy: 0.9917
# Epoch 173/200
#  - 0s - loss: 0.0462 - accuracy: 0.9833
# Epoch 174/200
#  - 0s - loss: 0.0493 - accuracy: 0.9750
# Epoch 175/200
#  - 0s - loss: 0.0444 - accuracy: 0.9833
# Epoch 176/200
#  - 0s - loss: 0.0454 - accuracy: 0.9833
# Epoch 177/200
#  - 0s - loss: 0.0409 - accuracy: 0.9833
# Epoch 178/200
#  - 0s - loss: 0.0457 - accuracy: 0.9750
# Epoch 179/200
#  - 0s - loss: 0.0402 - accuracy: 0.9917
# Epoch 180/200
#  - 0s - loss: 0.0400 - accuracy: 0.9917
# Epoch 181/200
#  - 0s - loss: 0.0401 - accuracy: 0.9917
# Epoch 182/200
#  - 0s - loss: 0.0399 - accuracy: 0.9833
# Epoch 183/200
#  - 0s - loss: 0.0410 - accuracy: 0.9833
# Epoch 184/200
#  - 0s - loss: 0.0408 - accuracy: 0.9917
# Epoch 185/200
#  - 0s - loss: 0.0386 - accuracy: 0.9833
# Epoch 186/200
#  - 0s - loss: 0.0400 - accuracy: 0.9833
# Epoch 187/200
#  - 0s - loss: 0.0393 - accuracy: 0.9833
# Epoch 188/200
#  - 0s - loss: 0.0368 - accuracy: 0.9917
# Epoch 189/200
#  - 0s - loss: 0.0379 - accuracy: 0.9917
# Epoch 190/200
#  - 0s - loss: 0.0369 - accuracy: 0.9917
# Epoch 191/200
#  - 0s - loss: 0.0367 - accuracy: 0.9917
# Epoch 192/200
#  - 0s - loss: 0.0414 - accuracy: 0.9917
# Epoch 193/200
#  - 0s - loss: 0.0418 - accuracy: 0.9917
# Epoch 194/200
#  - 0s - loss: 0.0374 - accuracy: 0.9917
# Epoch 195/200
#  - 0s - loss: 0.0397 - accuracy: 0.9833
# Epoch 196/200
#  - 0s - loss: 0.0398 - accuracy: 0.9833
# Epoch 197/200
#  - 0s - loss: 0.0358 - accuracy: 0.9833
# Epoch 198/200
#  - 0s - loss: 0.0357 - accuracy: 0.9917
# Epoch 199/200
#  - 0s - loss: 0.0350 - accuracy: 0.9917
# Epoch 200/200
#  - 0s - loss: 0.0384 - accuracy: 0.9917

# %%
# Test on unseen data

results = model.evaluate(test_x, test_y)
# Out:
# 30/30 [==============================] - 0s 3ms/step

# %%
print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))
# Out:
# Final test set loss: 0.151927
# Final test set accuracy: 0.966667
